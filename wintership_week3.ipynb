# %%
import pandas as pd
import os
import datetime

# %%
df = pd.read_csv("F:\\AIX Docs\\Data science\\Widhya Internship\\Week3\\covid19.csv")

# %%
df.head()
# Out:
#    Sno      Date State/UnionTerritory  ConfirmedIndianNational  \
# 0    1  30/01/20               Kerala                        1
# 1    2  31/01/20               Kerala                        1
# 2    3  01/02/20               Kerala                        2
# 3    4  02/02/20               Kerala                        3
# 4    5  03/02/20               Kerala                        3
#
#    ConfirmedForeignNational  Cured  Deaths
# 0                         0      0       0
# 1                         0      0       0
# 2                         0      0       0
# 3                         0      0       0
# 4                         0      0       0

# %%
df1=df[['Date','ConfirmedIndianNational','ConfirmedForeignNational','Cured','Deaths']]

# %%
df2=df1.groupby(by='Date',sort=False).sum()

# %%
df2
# Out:
#           ConfirmedIndianNational  ConfirmedForeignNational  Cured  Deaths
# Date
# 30/01/20                        1                         0      0       0
# 31/01/20                        1                         0      0       0
# 01/02/20                        2                         0      0       0
# 02/02/20                        3                         0      0       0
# 03/02/20                        3                         0      0       0
# 04/02/20                        3                         0      0       0
# 05/02/20                        3                         0      0       0
# 06/02/20                        3                         0      0       0
# 07/02/20                        3                         0      0       0
# 08/02/20                        3                         0      0       0
# 09/02/20                        3                         0      0       0
# ...

# %%
df2['Total_Cases']=df2.ConfirmedIndianNational+df2.ConfirmedForeignNational+df2.Cured+df2.Deaths

# %%
df2.index
# Out:
# Index(['30/01/20', '31/01/20', '01/02/20', '02/02/20', '03/02/20', '04/02/20',
#        '05/02/20', '06/02/20', '07/02/20', '08/02/20', '09/02/20', '10/02/20',
#        '11/02/20', '12/02/20', '13/02/20', '14/02/20', '15/02/20', '16/02/20',
#        '17/02/20', '18/02/20', '19/02/20', '20/02/20', '21/02/20', '22/02/20',
#        '23/02/20', '24/02/20', '25/02/20', '26/02/20', '27/02/20', '28/02/20',
#        '29/02/20', '01/03/20', '02/03/20', '03/03/20', '04/03/20', '05/03/20',
#        '06/03/20', '07/03/20', '08/03/20', '09/03/20', '10/03/20', '11/03/20',
#        '12/03/20', '13/03/20', '14/03/20', '15/03/20', '16/03/20', '17/03/20',
#        '18/03/20', '19/03/20', '20/03/20', '21/03/20'],
#       dtype='object', name='Date')

# %%
df2.columns
# Out:
# Index(['ConfirmedIndianNational', 'ConfirmedForeignNational', 'Cured',
#        'Deaths', 'Total_Cases'],
#       dtype='object')

# %%
df2.Total_Cases.plot()

# %%
df2.Total_Cases.plot(kind='bar')

# %%
df2[df2.index=='04/03/20']
# Out:
#           ConfirmedIndianNational  ConfirmedForeignNational  Cured  Deaths  \
# Date
# 04/03/20                       12                        16      3       0
#
#           Total_Cases
# Date
# 04/03/20           31

# %%
df2[df2.index=='04/03/20'].Total_Cases
# Out:
# Date
# 04/03/20    31
# Name: Total_Cases, dtype: int64

# %%
df2=df2.reset_index()

# %%
df2
# Out:
#         Date  ConfirmedIndianNational  ConfirmedForeignNational  Cured  \
# 0   30/01/20                        1                         0      0
# 1   31/01/20                        1                         0      0
# 2   01/02/20                        2                         0      0
# 3   02/02/20                        3                         0      0
# 4   03/02/20                        3                         0      0
# 5   04/02/20                        3                         0      0
# 6   05/02/20                        3                         0      0
# 7   06/02/20                        3                         0      0
# 8   07/02/20                        3                         0      0
# 9   08/02/20                        3                         0      0
# 10  09/02/20                        3                         0      0
# 11  10/02/20                        3                         0      0
# ...

# %%
df2['Date']=pd.to_datetime(df2['Date'], dayfirst=True)

# %%
df2
# Out:
#          Date  ConfirmedIndianNational  ConfirmedForeignNational  Cured  \
# 0  2020-01-30                        1                         0      0
# 1  2020-01-31                        1                         0      0
# 2  2020-02-01                        2                         0      0
# 3  2020-02-02                        3                         0      0
# 4  2020-02-03                        3                         0      0
# 5  2020-02-04                        3                         0      0
# 6  2020-02-05                        3                         0      0
# 7  2020-02-06                        3                         0      0
# 8  2020-02-07                        3                         0      0
# 9  2020-02-08                        3                         0      0
# 10 2020-02-09                        3                         0      0
# 11 2020-02-10                        3                         0      0
# ...

# %%
df2.columns
# Out:
# Index(['Date', 'ConfirmedIndianNational', 'ConfirmedForeignNational', 'Cured',
#        'Deaths', 'Total_Cases'],
#       dtype='object')

# %%
df3=df2[(df2['Date'] >= '2020-03-04') & (df2['Date'] <= '2020-03-21')]

# %%
df3
# Out:
#          Date  ConfirmedIndianNational  ConfirmedForeignNational  Cured  \
# 34 2020-03-04                       12                        16      3
# 35 2020-03-05                       14                        16      3
# 36 2020-03-06                       15                        16      3
# 37 2020-03-07                       18                        16      3
# 38 2020-03-08                       23                        16      3
# 39 2020-03-09                       30                        16      3
# 40 2020-03-10                       42                        16      3
# 41 2020-03-11                       44                        16      3
# 42 2020-03-12                       57                        17      3
# 43 2020-03-13                       64                        17      3
# 44 2020-03-14                       67                        17     10
# 45 2020-03-15                       93                        17     13
# ...

# %%
df3['r'] = (df3['Total_Cases'].shift(-1) - df3['Total_Cases'] ) / df3['Total_Cases']
# Out:
# C:\Users\Dinesh\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df3
# Out:
#          Date  ConfirmedIndianNational  ConfirmedForeignNational  Cured  \
# 34 2020-03-04                       12                        16      3
# 35 2020-03-05                       14                        16      3
# 36 2020-03-06                       15                        16      3
# 37 2020-03-07                       18                        16      3
# 38 2020-03-08                       23                        16      3
# 39 2020-03-09                       30                        16      3
# 40 2020-03-10                       42                        16      3
# 41 2020-03-11                       44                        16      3
# 42 2020-03-12                       57                        17      3
# 43 2020-03-13                       64                        17      3
# 44 2020-03-14                       67                        17     10
# 45 2020-03-15                       93                        17     13
# ...

# %%
import math

# %%
P_o=31
t=26
r=0.064516
P_t=P_o*(math.exp(r*t))

# %%
P_t
# Out:
# 165.90298743610091

# %%
int(P_t)
# Out:
# 165
